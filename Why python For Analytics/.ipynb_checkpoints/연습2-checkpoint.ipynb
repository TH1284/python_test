# %%
inputList = ["11","1234","222","555"]

# %%
i=0

# %%
inputList(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-9ea65917e724> in <module>
# ----> 1 inputList(i)
#
# TypeError: 'list' object is not callable

# %%
inputList = ["11","1234","222","555"]

def listSum(inputList):
    #inputList = ["11","1234","222","555"]
    i = 0
    sum = 0
    while (i < 4):
        if (type(inputList[i]) == str):
            sum = sum + int(inputList[i])
        elif (type(inputList[i]) == int):
            sum = sum +  inputList[i]    
        i = i+1
    return sum

listSum(inputList)

# %%
def List(value):
    i = 0
    while (i < 4):
        if (type(inputList(i)) == str):
            a = int(inputList(i))
        elif (type(inputList(i)) == int):
            b= sum(inputList(i))    
    i = i+1
    return b

# %%
List(inputList)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-a874dfa6bd9e> in <module>
# ----> 1 List(inputList)
#
# <ipython-input-40-b86168a415cb> in List(value)
#       2     i = 0
#       3     while (i < 4):
# ----> 4         if (type(inputList(i)) == str):
#       5             a = int(inputList(i))
#       6         elif (type(inputList(i)) == int):
#
# TypeError: 'list' object is not callable

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# PANDAS 패키지 불러오기
import pandas as pd 
import pymysql 
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://kopo:kopo@13.209.112.251:3306/kopo')

# %%
selloutData = pd.read_sql_query('SELECT * FROM kopo_product_volume', engine)
selloutData
# Out:
#     regionid productgroup yearweek     volume
# 0        A01       ST0002   201512   151750.0
# 1        A01       ST0001   201520   645626.0
# 2        A01       ST0002   201520   125863.0
# 3        A01       ST0001   201515   810144.0
# 4        A01       ST0002   201515   128999.0
# 5        A01       ST0001   201518   671464.0
# 6        A01       ST0002   201518   134467.0
# 7        A01       ST0001   201513   470040.0
# 8        A01       ST0002   201513   140297.0
# 9        A01       ST0001   201511   524787.0
# 10       A01       ST0002   201511   145509.0
# 11       A01       ST0001   201516   764927.0
# 12       A01       ST0002   201516   140313.0
# 13       A01       ST0001   201519   682757.0
# 14       A01       ST0002   201519   128668.0
# 15       A01       ST0001   201514   428195.0
# 16       A01       ST0002   201514   137488.0
# 17       A01       ST0001   201512   486509.0
# 18       A01       ST0001   201517   697502.0
# ...

# %%
selloutData.columns = ['AA','BB','CC','DD']
selloutData
# Out:
#       AA      BB      CC         DD
# 0    A01  ST0002  201512   151750.0
# 1    A01  ST0001  201520   645626.0
# 2    A01  ST0002  201520   125863.0
# 3    A01  ST0001  201515   810144.0
# 4    A01  ST0002  201515   128999.0
# 5    A01  ST0001  201518   671464.0
# 6    A01  ST0002  201518   134467.0
# 7    A01  ST0001  201513   470040.0
# 8    A01  ST0002  201513   140297.0
# 9    A01  ST0001  201511   524787.0
# 10   A01  ST0002  201511   145509.0
# 11   A01  ST0001  201516   764927.0
# 12   A01  ST0002  201516   140313.0
# 13   A01  ST0001  201519   682757.0
# 14   A01  ST0002  201519   128668.0
# 15   A01  ST0001  201514   428195.0
# 16   A01  ST0002  201514   137488.0
# 17   A01  ST0001  201512   486509.0
# 18   A01  ST0001  201517   697502.0
# 19   A01  ST0002  201517   127163.0
# 20   A01  ST0001  201507   620392.0
# 21   A01  ST0002  201507   146476.0
# 22   A01  ST0001  201510   511679.0
# 23   A01  ST0002  201510   153152.0
# 24   A01  ST0001  201502   438251.0
# ...

# %%
resultname='kopo_product_volume_임태현'
selloutData.to_sql(resultname, engine, if_exists='replace', index=False)

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# %%
engine_postgres = create_engine('postgresql://postgres:postgres@192.168.110.111:5432/kopo')

# %%
selloutData = pd.read_sql_query('SELECT * FROM kopo_product_volume_임태현', engine)
selloutData.head()
# Out:
#     AA      BB      CC        DD
# 0  A01  ST0002  201512  151750.0
# 1  A01  ST0001  201520  645626.0
# 2  A01  ST0002  201520  125863.0
# 3  A01  ST0001  201515  810144.0
# 4  A01  ST0002  201515  128999.0

# %%
resultname=' kopo_product_volume_임태현'
selloutData.to_sql(resultname, engine_postgres, if_exists='replace', index=False)
