# %%
import pandas as pd

# %%
customerdata = pd.read_csv('./dataset/customerdata.csv')
customerdata.head()
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634   3391.074215    2          4.2    2.453656      Sleeping-dog

# %%
customerdata[(customerdata.EMI > 3) & (customerdata.DEVICECOUNT >= 5)]
# Out:
# Empty DataFrame
# Columns: [CUSTID, AVERAGEPRICE, EMI, DEVICECOUNT, PRODUCTAGE, CUSTTYPE]
# Index: []

# %%
customerdata.dtypes
# Out:
# CUSTID           object
# AVERAGEPRICE    float64
# EMI               int64
# DEVICECOUNT     float64
# PRODUCTAGE      float64
# CUSTTYPE         object
# dtype: object

# %%
import pandas as pd

# %%
kopo_cust = pd.read_csv('./dataset/kopo_customerdata.csv')
kopo_cust
# Out:
#         CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0            1503989    State2   2    Male    0        1      1         0
# 1            1190338    State2   2    Male    0        1      0         1
# 2            1424715    State2   2  Female    0        2      0         0
# 3            2483305    State2   2    Male    0        1      0         1
# 4            1178802    State2   2    Male    0        1      0         1
# 5             859044    State2   2    Male    0        1      0         0
# 6             734198    State2   2  Female    0        2      0         0
# 7            1443485    State2   2  Female    0        2      0         0
# 8            2340520    State2   2    Male    0        1      0         1
# 9             697949    State2   2    Male    0        1      0         1
# 10            385031    State2   2    Male    0        1      0         1
# 11           1944258    State2   2  Female    0        2      0         0
# ...

# %%
kopo_cust[["CUSTOMERCODE","STATENAME","GENDER","TOTAL_AMOUNT"]]
# Out:
#         CUSTOMERCODE STATENAME  GENDER  TOTAL_AMOUNT
# 0            1503989    State2    Male         30300
# 1            1190338    State2    Male         46500
# 2            1424715    State2  Female         22700
# 3            2483305    State2    Male         31400
# 4            1178802    State2    Male         44900
# 5             859044    State2    Male         38300
# 6             734198    State2  Female         19900
# 7            1443485    State2  Female         14800
# 8            2340520    State2    Male         24400
# 9             697949    State2    Male         30400
# 10            385031    State2    Male         30300
# 11           1944258    State2  Female         34300
# 12           2029521    State2  Female         14900
# 13           1429192    State2    Male         16300
# 14            892851    State2    Male         25000
# 15           1554976    State2    Male         27500
# 16           1154228    State2    Male         18200
# ...

# %%
customerdata.iloc[0:1, 0:4]
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT
# 0  A13566        4273.9    3          6.4

# %%
kopo_cust.iloc[0:5, 1:4]
# Out:
#   STATENAME  ST  GENDER
# 0    State2   2    Male
# 1    State2   2    Male
# 2    State2   2  Female
# 3    State2   2    Male
# 4    State2   2    Male

# %%
kopo_cust.columns.get_loc("ST")
# Out:
# 2

# %%
kopo_cust.columns
# Out:
# Index(['CUSTOMERCODE', 'STATENAME', 'ST', 'GENDER', 'DOB', 'GENDER1', 'EMAIL',
#        'FEST_CNT', 'TOTAL_AMOUNT', 'AC_AMOUNT', 'AV_AMOUNT', 'HA_AMOUNT',
#        'EMI_CE_AMOUNT', 'IS_HIGHEND', 'CNT_VIST', 'GAP_VISIT'],
#       dtype='object')

# %%
kopo_custcolumns = kopo_cust.columns

# %%
csCodeColNo = kopo_custcolumns.get_loc("CUSTOMERCODE")

# %%
stColNo = kopo_custcolumns.get_loc("ST")

# %%
kopo_cust.iloc[:,[csCodeColNo,stColNo]]
# Out:
#         CUSTOMERCODE  ST
# 0            1503989   2
# 1            1190338   2
# 2            1424715   2
# 3            2483305   2
# 4            1178802   2
# 5             859044   2
# 6             734198   2
# 7            1443485   2
# 8            2340520   2
# 9             697949   2
# 10            385031   2
# 11           1944258   2
# 12           2029521   2
# 13           1429192   2
# 14            892851   2
# 15           1554976   2
# 16           1154228   2
# 17            816582   2
# 18            675948   2
# 19            965940   2
# 20           2636314   2
# 21            577344   2
# 22            910781   2
# 23            541107   2
# 24           1860112   2
# 25           1016762   2
# 26           2029821   2
# 27            765206   2
# 28           2174694   2
# 29           1196869   2
# ...              ...  ..
# 299970       2436525   1
# 299971       1238030   1
# 299972        923009   1
# 299973       1433055   1
# 299974       2639022   1
# ...

# %%
kopo_cust.loc[0:5, ["STATENAME", "GENDER"]]
# Out:
#   STATENAME  GENDER
# 0    State2    Male
# 1    State2    Male
# 2    State2  Female
# 3    State2    Male
# 4    State2    Male
# 5    State2    Male

# %%
kopo_cust.iloc[0:5, [1,3]]
# Out:
#   STATENAME  GENDER
# 0    State2    Male
# 1    State2    Male
# 2    State2  Female
# 3    State2    Male
# 4    State2    Male

# %%
import numpy as np

# %%
customerdata["PRODUCTAGE_NEW"] = np.where(customerdata["PRODUCTAGE"] < 1,1,\
                                np.where(customerdata["PRODUCTAGE"] < 2,2,\
                                np.where(customerdata["PRODUCTAGE"] < 3,3,\
                                5)))
customerdata.head()
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0  A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
#
#    PRODUCTAGE_NEW
# 0               2
# 1               3
# 2               5
# 3               1
# 4               3

# %% [markdown]
# ## 자료

# %%
import pandas as pd

# %%
kopoCS = pd.read_csv('./dataset/kopo_channel_seasonality_new.csv')
kopoCS
# Out:
#        REGIONID    PRODUCT  YEARWEEK       QTY
# 0           A60   PRODUCT4    201402      71.0
# 1           A60  PRODUCT59    201402   22275.0
# 2           A60  PRODUCT34    201402    4463.0
# 3           A60  PRODUCT47    201402       0.0
# 4           A60  PRODUCT56    201402      23.0
# 5           A60  PRODUCT57    201402      14.0
# 6           A60  PRODUCT12    201402    1186.0
# 7           A60   PRODUCT1    201402       7.0
# 8           A60  PRODUCT33    201402     101.0
# 9           A60  PRODUCT62    201402     336.0
# 10          A37  PRODUCT58    201402       0.0
# 11          A37  PRODUCT59    201402   11492.0
# 12          A37  PRODUCT34    201402     825.0
# 13          A31  PRODUCT58    201402       0.0
# 14          A31  PRODUCT59    201402     560.0
# 15          A31  PRODUCT34    201402     103.0
# 16          A04  PRODUCT58    201402       0.0
# 17          A04  PRODUCT63    201402     740.0
# 18          A04  PRODUCT15    201402     394.0
# ...

# %% [markdown]
# ## QTY 마이너스 값을 0으로 변경

# %%
import numpy as np

# %%
kopoCS["QTY_NEW"] = np.where(kopoCS["QTY"] < 0,0,kopoCS["QTY"])
kopoCS.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY  QTY_NEW
# 0      A60   PRODUCT4    201402     71.0     71.0
# 1      A60  PRODUCT59    201402  22275.0  22275.0
# 2      A60  PRODUCT34    201402   4463.0   4463.0
# 3      A60  PRODUCT47    201402      0.0      0.0
# 4      A60  PRODUCT56    201402     23.0     23.0

# %%
kopoCS.dtypes
# Out:
# REGIONID     object
# PRODUCT      object
# YEARWEEK      int64
# QTY         float64
# QTY_NEW     float64
# dtype: object

# %% [markdown]
# ## YEARWEEK를 타입str으로 변경

# %%
kopoCS["YEARWEEK"] = kopoCS["YEARWEEK"].astype(str)

# %%
kopoCS.columns
# Out:
# Index(['REGIONID', 'PRODUCT', 'YEARWEEK', 'QTY', 'QTY_NEW'], dtype='object')

# %%
kopoCS.dtypes
# Out:
# REGIONID     object
# PRODUCT      object
# YEARWEEK     object
# QTY         float64
# QTY_NEW     float64
# dtype: object

# %% [markdown]
# ## YEAR, WEEK 컬럼 생성

# %%
kopoCS["YEAR"] = kopoCS["YEARWEEK"].str[0:4]

# %%
kopoCS
# Out:
#        REGIONID    PRODUCT YEARWEEK       QTY   QTY_NEW  YEAR
# 0           A60   PRODUCT4   201402      71.0      71.0  2014
# 1           A60  PRODUCT59   201402   22275.0   22275.0  2014
# 2           A60  PRODUCT34   201402    4463.0    4463.0  2014
# 3           A60  PRODUCT47   201402       0.0       0.0  2014
# 4           A60  PRODUCT56   201402      23.0      23.0  2014
# 5           A60  PRODUCT57   201402      14.0      14.0  2014
# 6           A60  PRODUCT12   201402    1186.0    1186.0  2014
# 7           A60   PRODUCT1   201402       7.0       7.0  2014
# 8           A60  PRODUCT33   201402     101.0     101.0  2014
# 9           A60  PRODUCT62   201402     336.0     336.0  2014
# 10          A37  PRODUCT58   201402       0.0       0.0  2014
# 11          A37  PRODUCT59   201402   11492.0   11492.0  2014
# 12          A37  PRODUCT34   201402     825.0     825.0  2014
# 13          A31  PRODUCT58   201402       0.0       0.0  2014
# ...

# %%
kopoCS["WEEK"] = kopoCS["YEARWEEK"].str[4:6]

# %%
kopoCS
# Out:
#        REGIONID    PRODUCT YEARWEEK       QTY   QTY_NEW  YEAR WEEK
# 0           A60   PRODUCT4   201402      71.0      71.0  2014   02
# 1           A60  PRODUCT59   201402   22275.0   22275.0  2014   02
# 2           A60  PRODUCT34   201402    4463.0    4463.0  2014   02
# 3           A60  PRODUCT47   201402       0.0       0.0  2014   02
# 4           A60  PRODUCT56   201402      23.0      23.0  2014   02
# 5           A60  PRODUCT57   201402      14.0      14.0  2014   02
# 6           A60  PRODUCT12   201402    1186.0    1186.0  2014   02
# 7           A60   PRODUCT1   201402       7.0       7.0  2014   02
# 8           A60  PRODUCT33   201402     101.0     101.0  2014   02
# 9           A60  PRODUCT62   201402     336.0     336.0  2014   02
# 10          A37  PRODUCT58   201402       0.0       0.0  2014   02
# 11          A37  PRODUCT59   201402   11492.0   11492.0  2014   02
# 12          A37  PRODUCT34   201402     825.0     825.0  2014   02
# ...

# %% [markdown]
# ## WEEK를 타입 int로 변경

# %%
kopoCS["WEEK"] = kopoCS["WEEK"].astype(int)

# %%
kopoCS[kopoCS.WEEK == 53]
# Out:
#        REGIONID    PRODUCT YEARWEEK      QTY  QTY_NEW  YEAR  WEEK
# 62075       A64  PRODUCT63   201553   2092.0   2092.0  2015    53
# 62076       A64  PRODUCT15   201553     80.0     80.0  2015    53
# 62077       A64   PRODUCT4   201553   1781.0   1781.0  2015    53
# 62078       A64  PRODUCT16   201553      8.0      8.0  2015    53
# 62079       A64  PRODUCT59   201553  24242.0  24242.0  2015    53
# 62080       A64  PRODUCT34   201553   6586.0   6586.0  2015    53
# 62081       A64  PRODUCT40   201553      0.0      0.0  2015    53
# 62082       A64  PRODUCT60   201553      7.0      7.0  2015    53
# 62083       A64  PRODUCT56   201553     18.0     18.0  2015    53
# 62084       A64  PRODUCT61   201553      0.0      0.0  2015    53
# 62085       A64  PRODUCT12   201553  10913.0  10913.0  2015    53
# 62086       A64   PRODUCT1   201553    513.0    513.0  2015    53
# 62087       A64  PRODUCT33   201553     98.0     98.0  2015    53
# ...

# %% [markdown]
# ## WEEK가 52이하인 데이터 조회

# %%
kopoCS[kopoCS.WEEK < 53]
# Out:
#        REGIONID    PRODUCT YEARWEEK       QTY   QTY_NEW  YEAR  WEEK
# 0           A60   PRODUCT4   201402      71.0      71.0  2014     2
# 1           A60  PRODUCT59   201402   22275.0   22275.0  2014     2
# 2           A60  PRODUCT34   201402    4463.0    4463.0  2014     2
# 3           A60  PRODUCT47   201402       0.0       0.0  2014     2
# 4           A60  PRODUCT56   201402      23.0      23.0  2014     2
# 5           A60  PRODUCT57   201402      14.0      14.0  2014     2
# 6           A60  PRODUCT12   201402    1186.0    1186.0  2014     2
# 7           A60   PRODUCT1   201402       7.0       7.0  2014     2
# 8           A60  PRODUCT33   201402     101.0     101.0  2014     2
# 9           A60  PRODUCT62   201402     336.0     336.0  2014     2
# 10          A37  PRODUCT58   201402       0.0       0.0  2014     2
# 11          A37  PRODUCT59   201402   11492.0   11492.0  2014     2
# 12          A37  PRODUCT34   201402     825.0     825.0  2014     2
# ...

# %% [markdown]
# ## refinedSelloutData 변수에 담기

# %%
refinedSelloutData =kopoCS[kopoCS.WEEK < 53]

# %%
refinedSelloutData
# Out:
#        REGIONID    PRODUCT YEARWEEK       QTY   QTY_NEW  YEAR  WEEK
# 0           A60   PRODUCT4   201402      71.0      71.0  2014     2
# 1           A60  PRODUCT59   201402   22275.0   22275.0  2014     2
# 2           A60  PRODUCT34   201402    4463.0    4463.0  2014     2
# 3           A60  PRODUCT47   201402       0.0       0.0  2014     2
# 4           A60  PRODUCT56   201402      23.0      23.0  2014     2
# 5           A60  PRODUCT57   201402      14.0      14.0  2014     2
# 6           A60  PRODUCT12   201402    1186.0    1186.0  2014     2
# 7           A60   PRODUCT1   201402       7.0       7.0  2014     2
# 8           A60  PRODUCT33   201402     101.0     101.0  2014     2
# 9           A60  PRODUCT62   201402     336.0     336.0  2014     2
# 10          A37  PRODUCT58   201402       0.0       0.0  2014     2
# 11          A37  PRODUCT59   201402   11492.0   11492.0  2014     2
# 12          A37  PRODUCT34   201402     825.0     825.0  2014     2
# ...

# %% [markdown]
# ## 확인

# %%
refinedSelloutData[refinedSelloutData.WEEK == 53]
# Out:
# Empty DataFrame
# Columns: [REGIONID, PRODUCT, YEARWEEK, QTY, QTY_NEW, YEAR, WEEK]
# Index: []

# %%
def refining(df):
    if df['PRODUCTAGE'] < 1:
        return 1
    elif df['PRODUCTAGE'] <2:
        return 2
    else:
        return 5

# %% [markdown]
# ## 데이터 정제하기

# %%
customerdata["PRODUCTAGE_NEW2"] = customerdata.apply(refining, axis = 1)
customerdata
# Out:
#      CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849   3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816   3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639   3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717   3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050   4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306   4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %%
sortedData = customerdata.sort_values(["EMI","DEVICECOUNT"],ascending=[True,False], inplace=False)

# %%
sortedData.head()
# Out:
#     CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 68  N14862   2390.083736    1          6.3    1.000000        Early-bird
# 11  C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
# 72  O13037   3398.216334    1          4.5    2.994395      Sleeping-dog
# 56  K10712   3419.462596    1          4.4    2.825790      Sleeping-dog
# 46  I14835   3374.091339    1          4.0    2.749678      Sleeping-dog
#
#     PRODUCTAGE_NEW  PRODUCTAGE_NEW2
# 68               2                2
# 11               2                2
# 72               3                5
# 56               3                5
# 46               3                5

# %%
sortkey = ["PRODUCTAGE"]

# %%
customerdata.sort_values(sortkey ,inplace=True)
customerdata
# Out:
#      CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 51   J10809   3676.135627    3          6.5    0.800000        Early-bird
# 53   J16445   3041.848186    3          6.4    0.800000        Early-bird
# 13   D11795   2991.014703    2          6.4    0.800000        Early-bird
# 37   G19717   2873.102202    2          6.5    0.800000        Early-bird
# 80   P19679   3256.152962    2          6.1    0.800000        Early-bird
# 24   F10222   3191.065822    2          6.5    0.900000        Early-bird
# 23   E19404   3764.940414    2          6.5    0.900000        Early-bird
# 78   P18446   3168.567321    2          6.5    0.900000        Early-bird
# 77   P14740   3301.586463    2          6.5    0.900000        Early-bird
# 71   O12193   3491.983316    2          6.4    0.900000        Early-bird
# 62   L17101   3310.792459    2          6.5    0.900000        Early-bird
# 38   H10188   4020.245162    2          6.7    0.900000        Early-bird
# ...

# %% [markdown]
# ## 데이터 요약분석하기

# %%
groupkey = ["CUSTTYPE"]

# %%
meanValue = customerdata.\
groupby(groupkey).\
mean()
meanValue
# Out:
#                   AVERAGEPRICE   EMI  DEVICECOUNT  PRODUCTAGE  PRODUCTAGE_NEW  \
# CUSTTYPE
# Big-Screen-lover   3564.108000  2.04        5.552    2.193531            2.76
# Early-bird         3287.125090  2.30        6.462    0.946000            1.32
# Sleeping-dog       3446.990233  1.82        4.260    2.658271            3.34
#
#                   PRODUCTAGE_NEW2
# CUSTTYPE
# Big-Screen-lover             4.04
# Early-bird                   1.32
# Sleeping-dog                 4.82

# %%
meanValue.reset_index()
meanValue
# Out:
#                   AVERAGEPRICE   EMI  DEVICECOUNT  PRODUCTAGE  PRODUCTAGE_NEW  \
# CUSTTYPE
# Big-Screen-lover   3564.108000  2.04        5.552    2.193531            2.76
# Early-bird         3287.125090  2.30        6.462    0.946000            1.32
# Sleeping-dog       3446.990233  1.82        4.260    2.658271            3.34
#
#                   PRODUCTAGE_NEW2
# CUSTTYPE
# Big-Screen-lover             4.04
# Early-bird                   1.32
# Sleeping-dog                 4.82

# %%
groupkey2 = ['REGIONID','PRODUCT']

# %%
groupData = kopoCS.\
groupby(groupkey2).agg\
(['mean','std'])['QTY_NEW']
groupData
# Out:
#                              mean            std
# REGIONID PRODUCT
# A00      PRODUCT34     132.445860     154.867743
#          PRODUCT58     105.235669     273.435108
#          PRODUCT59   36086.547771   15192.174914
# A01      PRODUCT1     5716.726115    3704.948589
#          PRODUCT12  197052.777070  198866.717131
#          PRODUCT14   17934.738854    9402.640836
#          PRODUCT15    4759.554140    1528.260828
#          PRODUCT16    1392.394904     734.344988
#          PRODUCT19    3335.140127     996.017547
#          PRODUCT2    22769.891720   23307.183239
#          PRODUCT20      63.254777      75.729859
#          PRODUCT33   11919.828025    6300.941637
#          PRODUCT34  108633.229299  117445.576337
#          PRODUCT4    25851.547771   32905.547789
#          PRODUCT47   10998.159236    8243.442040
#          PRODUCT56    6296.229299    1832.616295
#          PRODUCT57    6804.643312    1391.225843
#          PRODUCT58   27346.216561   28091.461510
# ...

# %%
groupResult = groupData.reset_index()
groupResult
# Out:
#     REGIONID    PRODUCT           mean            std
# 0        A00  PRODUCT34     132.445860     154.867743
# 1        A00  PRODUCT58     105.235669     273.435108
# 2        A00  PRODUCT59   36086.547771   15192.174914
# 3        A01   PRODUCT1    5716.726115    3704.948589
# 4        A01  PRODUCT12  197052.777070  198866.717131
# 5        A01  PRODUCT14   17934.738854    9402.640836
# 6        A01  PRODUCT15    4759.554140    1528.260828
# 7        A01  PRODUCT16    1392.394904     734.344988
# 8        A01  PRODUCT19    3335.140127     996.017547
# 9        A01   PRODUCT2   22769.891720   23307.183239
# 10       A01  PRODUCT20      63.254777      75.729859
# 11       A01  PRODUCT33   11919.828025    6300.941637
# 12       A01  PRODUCT34  108633.229299  117445.576337
# 13       A01   PRODUCT4   25851.547771   32905.547789
# 14       A01  PRODUCT47   10998.159236    8243.442040
# 15       A01  PRODUCT56    6296.229299    1832.616295
# ...

# %%
groupkey3 = ['EMI']

# %%
groupData3 = customerdata.\
groupby(groupkey3).\
max()
groupData3
# Out:
#      CUSTID  AVERAGEPRICE  DEVICECOUNT  PRODUCTAGE      CUSTTYPE  \
# EMI
# 1    Y12458   3419.462596          6.3    2.994395  Sleeping-dog
# 2    Z19835   4166.533130          6.9    3.483573  Sleeping-dog
# 3    Z13534   4296.873743          6.9    2.055707    Early-bird
#
#      PRODUCTAGE_NEW  PRODUCTAGE_NEW2
# EMI
# 1                 3                5
# 2                 5                5
# 3                 3                5

# %%
sortedData = kopoCS.sort_values(["REGIONID","PRODUCT","YEARWEEK"], ascending = [True,True,True])

# %%
sortedData
# Out:
#        REGIONID    PRODUCT YEARWEEK      QTY  QTY_NEW  YEAR  WEEK
# 298         A00  PRODUCT34   201401    661.0    661.0  2014     1
# 1757        A00  PRODUCT34   201402    679.0    679.0  2014     2
# 3125        A00  PRODUCT34   201403    578.0    578.0  2014     3
# 205         A00  PRODUCT34   201404    532.0    532.0  2014     4
# 4369        A00  PRODUCT34   201405    516.0    516.0  2014     5
# 4313        A00  PRODUCT34   201406    423.0    423.0  2014     6
# 6288        A00  PRODUCT34   201407    407.0    407.0  2014     7
# 6403        A00  PRODUCT34   201408    364.0    364.0  2014     8
# 5158        A00  PRODUCT34   201409    470.0    470.0  2014     9
# 7437        A00  PRODUCT34   201410    538.0    538.0  2014    10
# 10123       A00  PRODUCT34   201411    369.0    369.0  2014    11
# 8844        A00  PRODUCT34   201412    352.0    352.0  2014    12
# 10813       A00  PRODUCT34   201413    354.0    354.0  2014    13
# ...

# %%
groupkey4 = ["REGIONID","PRODUCT","YEAR"]

# %%
groupData4 = sortedData.\
groupby(groupkey4).agg\
(['mean','std'])['QTY_NEW']
groupData4
# Out:
#                                   mean            std
# REGIONID PRODUCT   YEAR
# A00      PRODUCT34 2014     275.961538     162.179634
#                    2015      85.698113      72.858024
#                    2016      36.576923      94.897539
#          PRODUCT58 2014       2.673077       3.889257
#                    2015       7.547170      14.909427
#                    2016     307.365385     407.622857
#          PRODUCT59 2014   27418.692308   11461.345740
#                    2015   52315.679245    8241.607554
#                    2016   28213.173077    9583.361555
# A01      PRODUCT1  2014    8622.461538    3142.837761
#                    2015    6383.811321    2536.927101
#                    2016    2131.076923    1835.068015
#          PRODUCT12 2014  169397.826923  176743.049878
#                    2015  196178.811321  192959.986155
#                    2016  225598.500000  223957.833468
#          PRODUCT14 2014   12495.769231    6870.540503
# ...

# %%
groupResult2 = groupData4.reset_index()
groupResult2
# Out:
#      REGIONID    PRODUCT  YEAR           mean            std
# 0         A00  PRODUCT34  2014     275.961538     162.179634
# 1         A00  PRODUCT34  2015      85.698113      72.858024
# 2         A00  PRODUCT34  2016      36.576923      94.897539
# 3         A00  PRODUCT58  2014       2.673077       3.889257
# 4         A00  PRODUCT58  2015       7.547170      14.909427
# 5         A00  PRODUCT58  2016     307.365385     407.622857
# 6         A00  PRODUCT59  2014   27418.692308   11461.345740
# 7         A00  PRODUCT59  2015   52315.679245    8241.607554
# 8         A00  PRODUCT59  2016   28213.173077    9583.361555
# 9         A01   PRODUCT1  2014    8622.461538    3142.837761
# 10        A01   PRODUCT1  2015    6383.811321    2536.927101
# 11        A01   PRODUCT1  2016    2131.076923    1835.068015
# 12        A01  PRODUCT12  2014  169397.826923  176743.049878
# 13        A01  PRODUCT12  2015  196178.811321  192959.986155
# ...

# %%
groupResult2.columns=["REGIONID","PRODUCT","YEAR","QTY_MEAN","QTY_STD"]
groupResult2
# Out:
#      REGIONID    PRODUCT  YEAR       QTY_MEAN        QTY_STD
# 0         A00  PRODUCT34  2014     275.961538     162.179634
# 1         A00  PRODUCT34  2015      85.698113      72.858024
# 2         A00  PRODUCT34  2016      36.576923      94.897539
# 3         A00  PRODUCT58  2014       2.673077       3.889257
# 4         A00  PRODUCT58  2015       7.547170      14.909427
# 5         A00  PRODUCT58  2016     307.365385     407.622857
# 6         A00  PRODUCT59  2014   27418.692308   11461.345740
# 7         A00  PRODUCT59  2015   52315.679245    8241.607554
# 8         A00  PRODUCT59  2016   28213.173077    9583.361555
# 9         A01   PRODUCT1  2014    8622.461538    3142.837761
# 10        A01   PRODUCT1  2015    6383.811321    2536.927101
# 11        A01   PRODUCT1  2016    2131.076923    1835.068015
# 12        A01  PRODUCT12  2014  169397.826923  176743.049878
# 13        A01  PRODUCT12  2015  196178.811321  192959.986155
# ...

# %%
customerdata["TEST"] = customerdata["DEVICECOUNT"].rolling(window = 5, center = False).mean()
customerdata
# Out:
#      CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 51   J10809   3676.135627    3          6.5    0.800000        Early-bird
# 53   J16445   3041.848186    3          6.4    0.800000        Early-bird
# 13   D11795   2991.014703    2          6.4    0.800000        Early-bird
# 37   G19717   2873.102202    2          6.5    0.800000        Early-bird
# 80   P19679   3256.152962    2          6.1    0.800000        Early-bird
# 24   F10222   3191.065822    2          6.5    0.900000        Early-bird
# 23   E19404   3764.940414    2          6.5    0.900000        Early-bird
# 78   P18446   3168.567321    2          6.5    0.900000        Early-bird
# 77   P14740   3301.586463    2          6.5    0.900000        Early-bird
# 71   O12193   3491.983316    2          6.4    0.900000        Early-bird
# 62   L17101   3310.792459    2          6.5    0.900000        Early-bird
# 38   H10188   4020.245162    2          6.7    0.900000        Early-bird
# ...

# %%
import pandas as pd

# %%
regionMasterData = pd.read_csv('./dataset/kopo_region_mst.csv')
regionMasterData
# Out:
#    REGIONID REGIONNAME
# 0       A00     AFRICA
# 1       A01    AMERICA
# 2       A02      KOREA
# 3       A03     GERMAN
# 4       A04     BRAZIL
# 5       A05       ARAB
# 6       A06     ANGOLA
# 7       A07     BEEGIE
# 8       A08   BULGARIA
# 9       A09     BAREIL
# 10      A10        BOB
# 11      A11    BOLIVIA
# 12      A12     CANADA
# 13      A13      SWISS
# 14      A14     CHILLE
# 15      A15      CHINA
# 16      A16   COLOMBIA
# 17      A17  COSTARICA
# 18      A18    DENMARK
# 19      A19     ALGERI
# 20      A20      EGYPT
# 21      A21      SPAIN
# 22      A22    PINLAND
# 23      A23     FRANCE
# 24      A24        ENG
# 25      A25       GANA
# 26      A26     GREECE
# 27      A27       GUAM
# 28      A28   HONGKONG
# 29      A29         IT
# ..      ...        ...
# 43      A43     NETHER
# 44      A44     MAXICO
# 45      A45      NEPAL
# 46      A46        NEW
# 47      A47        PIL
# 48      A48        POL
# 49      A49        POR
# 50      A50    RUMANIA
# ...

# %%
selectExample = pd.read_csv('./dataset/kopo_channel_seasonality_new.csv')
selectExample
# Out:
#        REGIONID    PRODUCT  YEARWEEK       QTY
# 0           A60   PRODUCT4    201402      71.0
# 1           A60  PRODUCT59    201402   22275.0
# 2           A60  PRODUCT34    201402    4463.0
# 3           A60  PRODUCT47    201402       0.0
# 4           A60  PRODUCT56    201402      23.0
# 5           A60  PRODUCT57    201402      14.0
# 6           A60  PRODUCT12    201402    1186.0
# 7           A60   PRODUCT1    201402       7.0
# 8           A60  PRODUCT33    201402     101.0
# 9           A60  PRODUCT62    201402     336.0
# 10          A37  PRODUCT58    201402       0.0
# 11          A37  PRODUCT59    201402   11492.0
# 12          A37  PRODUCT34    201402     825.0
# 13          A31  PRODUCT58    201402       0.0
# 14          A31  PRODUCT59    201402     560.0
# 15          A31  PRODUCT34    201402     103.0
# 16          A04  PRODUCT58    201402       0.0
# 17          A04  PRODUCT63    201402     740.0
# 18          A04  PRODUCT15    201402     394.0
# ...

# %%
refinedSelloutData
# Out:
#        REGIONID    PRODUCT YEARWEEK       QTY   QTY_NEW  YEAR  WEEK
# 0           A60   PRODUCT4   201402      71.0      71.0  2014     2
# 1           A60  PRODUCT59   201402   22275.0   22275.0  2014     2
# 2           A60  PRODUCT34   201402    4463.0    4463.0  2014     2
# 3           A60  PRODUCT47   201402       0.0       0.0  2014     2
# 4           A60  PRODUCT56   201402      23.0      23.0  2014     2
# 5           A60  PRODUCT57   201402      14.0      14.0  2014     2
# 6           A60  PRODUCT12   201402    1186.0    1186.0  2014     2
# 7           A60   PRODUCT1   201402       7.0       7.0  2014     2
# 8           A60  PRODUCT33   201402     101.0     101.0  2014     2
# 9           A60  PRODUCT62   201402     336.0     336.0  2014     2
# 10          A37  PRODUCT58   201402       0.0       0.0  2014     2
# 11          A37  PRODUCT59   201402   11492.0   11492.0  2014     2
# 12          A37  PRODUCT34   201402     825.0     825.0  2014     2
# ...

# %%
groupResult2
# Out:
#      REGIONID    PRODUCT  YEAR       QTY_MEAN        QTY_STD
# 0         A00  PRODUCT34  2014     275.961538     162.179634
# 1         A00  PRODUCT34  2015      85.698113      72.858024
# 2         A00  PRODUCT34  2016      36.576923      94.897539
# 3         A00  PRODUCT58  2014       2.673077       3.889257
# 4         A00  PRODUCT58  2015       7.547170      14.909427
# 5         A00  PRODUCT58  2016     307.365385     407.622857
# 6         A00  PRODUCT59  2014   27418.692308   11461.345740
# 7         A00  PRODUCT59  2015   52315.679245    8241.607554
# 8         A00  PRODUCT59  2016   28213.173077    9583.361555
# 9         A01   PRODUCT1  2014    8622.461538    3142.837761
# 10        A01   PRODUCT1  2015    6383.811321    2536.927101
# 11        A01   PRODUCT1  2016    2131.076923    1835.068015
# 12        A01  PRODUCT12  2014  169397.826923  176743.049878
# 13        A01  PRODUCT12  2015  196178.811321  192959.986155
# ...

# %%
mergeResult = pd.merge(refinedSelloutData,groupResult2,\
        left_on = ["REGIONID","PRODUCT","YEAR"],right_on = ["REGIONID","PRODUCT","YEAR"])\
[["REGIONID","PRODUCT","YEARWEEK","YEAR","WEEK","QTY_NEW","QTY_MEAN","QTY_STD"]]
mergeResult.head()
# Out:
#   REGIONID   PRODUCT YEARWEEK  YEAR  WEEK  QTY_NEW   QTY_MEAN    QTY_STD
# 0      A60  PRODUCT4   201402  2014     2     71.0  29.134615  13.225093
# 1      A60  PRODUCT4   201401  2014     1     16.0  29.134615  13.225093
# 2      A60  PRODUCT4   201403  2014     3     51.0  29.134615  13.225093
# 3      A60  PRODUCT4   201406  2014     6     19.0  29.134615  13.225093
# 4      A60  PRODUCT4   201404  2014     4     21.0  29.134615  13.225093
