# %%
import pandas as pd
from isoweek import Week

# %% [markdown]
# ### 1. promotion Data 불러오기

# %%
promotionData = pd.read_csv("./data/pro_promotion.csv")

# %%
promotionData.head()
# Out:
#   regionseg      salesid productgroup      item  targetweek  planwee  \
# 0       A01  SALESID0001         PG03  ITEM0200      201631   201619
# 1       A01  SALESID0001         PG04  ITEM0285      201606   201601
# 2       A01  SALESID0001         PG04  ITEM0285      201607   201601
# 3       A01  SALESID0001         PG04  ITEM0285      201608   201601
# 4       A01  SALESID0001         PG04  ITEM0285      201609   201601
#
#    map_price   ir  pmap  pmap10  pro_percent
# 0          0  278  -278    -251     0.250000
# 1       3199  756  2443    2199     0.312598
# 2       3199  756  2443    2199     0.312598
# 3       3199  756  2443    2199     0.312598
# 4       3199  533  2666    2399     0.250078

# %%
promotionData.dtypes
# Out:
# regionseg        object
# salesid          object
# productgroup     object
# item             object
# targetweek        int64
# planwee           int64
# map_price         int64
# ir                int64
# pmap              int64
# pmap10            int64
# pro_percent     float64
# dtype: object

# %% [markdown]
# ## 2. planweek가 targetweek보다 큰 데이터 정제

# %%
step1proData= promotionData[promotionData.targetweek >= promotionData.planwee]

# %%
step1proData.head()
# Out:
#   regionseg      salesid productgroup      item  targetweek  planwee  \
# 0       A01  SALESID0001         PG03  ITEM0200      201631   201619
# 1       A01  SALESID0001         PG04  ITEM0285      201606   201601
# 2       A01  SALESID0001         PG04  ITEM0285      201607   201601
# 3       A01  SALESID0001         PG04  ITEM0285      201608   201601
# 4       A01  SALESID0001         PG04  ITEM0285      201609   201601
#
#    map_price   ir  pmap  pmap10  pro_percent
# 0          0  278  -278    -251     0.250000
# 1       3199  756  2443    2199     0.312598
# 2       3199  756  2443    2199     0.312598
# 3       3199  756  2443    2199     0.312598
# 4       3199  533  2666    2399     0.250078

# %%
## 정제한 후 인덱스 초기화
step1proData = step1proData.reset_index(drop=True)

# %% [markdown]
# ## 1. actual_sales 데이터 정리

# %%
actualData = pd.read_csv("./data/pro_actual_sales.csv")

# %%
## week가 52주차 이하인 값들을 뽑아서 actualData에 담기
actualData = actualData[actualData['week'] <= 52]
## 잘 정제 됬는지 확인
actualData[actualData['week'] > 52]
# Out:
# Empty DataFrame
# Columns: [regionSeg1, productSeg1, productSeg2, regionSeg2, regionSeg3, productSeg3, yearweek, year, week, qty]
# Index: []

# %%
actualData.head()
# Out:
#   regionSeg1  productSeg1 productSeg2   regionSeg2  regionSeg3 productSeg3  \
# 0        A01          NaN        PG05  SALESID0001  SITEID0004    ITEM0445
# 1        A01          NaN        PG05  SALESID0001  SITEID0004    ITEM0445
# 2        A01          NaN        PG05  SALESID0001  SITEID0004    ITEM0445
# 3        A01          NaN        PG05  SALESID0001  SITEID0004    ITEM0445
# 4        A01          NaN        PG05  SALESID0001  SITEID0004    ITEM0445
#
#    yearweek  year  week  qty
# 0    201306  2013     6    5
# 1    201307  2013     7    8
# 2    201308  2013     8    7
# 3    201309  2013     9    1
# 4    201310  2013    10    1

# %%
actualData.dtypes
# Out:
# regionSeg1      object
# productSeg1    float64
# productSeg2     object
# regionSeg2      object
# regionSeg3      object
# productSeg3     object
# yearweek         int64
# year             int64
# week             int64
# qty              int64
# dtype: object

# %%
groupKey = ['regionSeg1','productSeg2','regionSeg2','regionSeg3','productSeg3']

# %%
## 그룹바이 : 중복되는 주차가 없도록 1차 그룹바이

# %%
# Out:
#   File "<ipython-input-188-f87512eb5e8b>", line 1
#     ./
#     ^
# SyntaxError: invalid syntax

# %%
def minmaxweek(inputdf) :
    minweek = inputdf['yearweek'].min()
    maxweek = inputdf['yearweek'].max()
    
    for i in inputdf['yearweek']:

# %%
groupData = actualData.groupby(groupKey).apply(minmaxweek)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-483-f798eb7ce493> in <module>()
# ----> 1 groupData = actualData.groupby(groupKey).apply(minmaxweek)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in apply(self, func, *args, **kwargs)
#     803         # ignore SettingWithCopy here in case the user mutates
#     804         with option_context('mode.chained_assignment', None):
# --> 805             return self._python_apply_general(f)
#     806
#     807     def _python_apply_general(self, f):
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in _python_apply_general(self, f)
#     807     def _python_apply_general(self, f):
#     808         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 809                                                    self.axis)
#     810
#     811         return self._wrap_applied_output(
#
# ...

# %%
actualData.head()
# Out:
#   regionSeg1  productSeg1 productSeg2   regionSeg2  regionSeg3 productSeg3  \
# 0        A01          NaN        PG05  SALESID0001  SITEID0004    ITEM0445
# 1        A01          NaN        PG05  SALESID0001  SITEID0004    ITEM0445
# 2        A01          NaN        PG05  SALESID0001  SITEID0004    ITEM0445
# 3        A01          NaN        PG05  SALESID0001  SITEID0004    ITEM0445
# 4        A01          NaN        PG05  SALESID0001  SITEID0004    ITEM0445
#
#    yearweek  year  week  qty
# 0    201306  2013     6    5
# 1    201307  2013     7    8
# 2    201308  2013     8    7
# 3    201309  2013     9    1
# 4    201310  2013    10    1

# %%
yearweekList = [201501,201502,201505]

# %%
itemList = ['item0445','item0445','item0445']

# %%
qtyList = [5,7,4]

# %%
qtydf = pd.DataFrame(qtyList)

# %%
itemdf = pd.DataFrame(itemList)

# %%
yearweekdf = pd.DataFrame(yearweekList)

# %%
a = pd.concat([itemdf,yearweekdf,qtydf],axis=1)

# %%
a.columns
# Out:
# Int64Index([0, 0, 0], dtype='int64')

# %%
a.columns = ['items','yearweek','qty']

# %%
a
# Out:
#       items  yearweek  qty
# 0  item0445    201501    5
# 1  item0445    201502    7
# 2  item0445    201505    4

# %%
a.reset_indexs('yearweek')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-417-f240da67f06b> in <module>()
# ----> 1 a.reset_indexs('yearweek')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'reset_indexs'

# %%
minyearweek = a.yearweek.min()

# %%
maxyearweek = a.yearweek.max()

# %%
minyearweek
# Out:
# 201501

# %%
fullyearweek = []

# %%
fullyearweek.append(minyearweek)

# %%
fullyearweek.append(maxyearweek)

# %%
fullyearweek
# Out:
# [201501, 201505]

# %%
fullyearweek= []

# %%
i = minyearweek

# %%
fullyearweek.append(i)

# %%
fullyearweek
# Out:
# [201501]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-476-24a0223b42c5> in <module>()
# ----> 1 fullyearweek.values()
#
# AttributeError: 'list' object has no attribute 'values'

# %%
while (max(fullyearweek) < 201505):
    fullyearweek.append(i+1)
    i = i + 1

# %%
newyearweekList = list(set(fullyearweek).difference(set(list(a.yearweek.values))))

# %%
newyearweekList
# Out:
# [201504, 201503]

# %%
a.loc[3] =["item0445",201505,3]

# %%
a.loc[4,'yearweek'] = 201503

# %%
a.loc[len(a)+1,'yearweek'] = 201503

# %%
a.loc[len(a)+1,'yearweek']
# Out:
#              items  yearweek       qty
# 0         item0445  201501.0       5.0
# 1         item0445  201502.0       7.0
# 2         item0445  201505.0       4.0
# 3         item0445  201505.0       3.0
# 4              NaN  201503.0       NaN
# yearweek    201505  201505.0  201505.0
# 6              NaN  201505.0       NaN
# 9              NaN  201503.0       NaN
# 8              NaN  201503.0       NaN
# 10             NaN  201503.0       NaN
# 11             NaN  201503.0       NaN
# 12             NaN  201503.0       NaN

# %%
a['']

# %%
a['yearweek'].sort
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-390-5d560b7bdb1b> in <module>()
# ----> 1 a['yearweek'].sort
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'sort'

# %%
min(a['yearweek'])
# Out:
# 201501.0

# %%
a.set_indexs('yearweek')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-404-bb0fdf1e9031> in <module>()
# ----> 1 a.set_indexs('yearweek')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'set_indexs'

# %%
a.sort_values('yearweek')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-394-dd63d5677124> in <module>()
#       1 a.sort_values('yearweek')
# ----> 2 a.reset_indexs()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'reset_indexs'

# %%
def minmaxweek(inputdf) :
    minweek = min(inputdf['yearweek'])
    maxweek = max(inputdf['yearweek'])
    fullyearweek = []
    i = minweek
    fullyearweek.append(i)
    while (max(fullyearweek) < maxweek):
        fullyearweek.append(i+1)
        i= i + 1
    newyearweekList = list(set(fullyearweek).difference(set(list(inputdf.yearweek.values))))

    for i in len(newyearweekList):
        inputdf.loc[len(inputdf),'yearweek'] = newyearweekList[i]
    inputdf.sort_values('yearweek')

# %%
eachData = groupData.get_group()
# Out:
# 201502

# %%
groupData.head()
# Out:
#        regionSeg1  productSeg1 productSeg2   regionSeg2  regionSeg3  \
# 0             A01          NaN        PG05  SALESID0001  SITEID0004
# 1             A01          NaN        PG05  SALESID0001  SITEID0004
# 2             A01          NaN        PG05  SALESID0001  SITEID0004
# 3             A01          NaN        PG05  SALESID0001  SITEID0004
# 4             A01          NaN        PG05  SALESID0001  SITEID0004
# 42            A01          NaN        PG05  SALESID0001  SITEID0003
# 43            A01          NaN        PG05  SALESID0001  SITEID0003
# 44            A01          NaN        PG05  SALESID0001  SITEID0003
# 45            A01          NaN        PG05  SALESID0001  SITEID0003
# 46            A01          NaN        PG05  SALESID0001  SITEID0003
# 76            A01          NaN        PG05  SALESID0001  SITEID0002
# 77            A01          NaN        PG05  SALESID0001  SITEID0002
# 78            A01          NaN        PG05  SALESID0001  SITEID0002
# ...

# %%
a.reset_indexs()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-421-76fdf9db0cc4> in <module>()
# ----> 1 a.reset_indexs()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'reset_indexs'

# %%
a
# Out:
# [201502, 201503]

# %%
minweek = min(a['yearweek'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-434-b749ee31a7bc> in <module>()
# ----> 1 minweek = min(a['yearweek'])
#
# TypeError: list indices must be integers or slices, not str

# %%
maxweek = max(a['yearweek'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-435-9f476c59a3f3> in <module>()
# ----> 1 maxweek = max(a['yearweek'])
#
# TypeError: list indices must be integers or slices, not str

# %%
minweek
# Out:
# 201501.0

# %%
fullyearweek
# Out:
# [201501, 201502, 201503, 201504, 201505]

# %%
a
# Out:
#       items  yearweek  qty
# 0  item0445    201501    5
# 1  item0445    201502    7
# 2  item0445    201505    4

# %%
fullyearweek = []

# %%
i = minweek

# %%
fullyearweek.append(i)

# %%
while (max(fullyearweek) < maxweek):
        fullyearweek.append(i+1)
        i= i + 1

# %%
fullyearweek
# Out:
# [201501.0, 201502.0, 201503.0, 201504.0, 201505.0]

# %%
fullyearweek
# Out:
# [201501.0, 201502.0, 201503.0, 201504.0, 201505.0]

# %%
a = [201502,201503]

# %%
set(a)
# Out:
# {201502, 201503}

# %%
newyearweekList = list(set(fullyearweek).difference(set(list(str(inputdf.yearweek.values))))
# Out:
#   File "<ipython-input-433-70373c8ea8d9>", line 1
#     newyearweekList = list(set(fullyearweek).difference(set(list(str(inputdf.yearweek.values))))
#                                                                                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
newyearweekList = [201502,201503]

# %%
newyearweekdf = pd.DataFrame(newyearweekList)

# %%
newyearweekdf.columns = ['yearweek']

# %%
for i in newyearweekdf['yearweek']:
    newyearweekdf[i]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 201502
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-360-6dab2ed6b382> in <module>()
#       1 for i in newyearweekdf['yearweek']:
# ...

# %%
fullyearweek = [min~max]
inputdf = [min ~ max empty]
emptylist = 
201501 ,201503

# %%
a
# Out:
#       items  yearweek  qty
# 0  item0445  201501.0  5.0
# 1  item0445  201502.0  7.0
# 2  item0445  201505.0  4.0
# 3  item0445  201505.0  3.0
# 4       NaN  201503.0  NaN

# %%
set(list(a.yearweek.values))
# Out:
# {201501, 201502, 201505}

# %%
emptyyearweek = set(fullyearweek) - set(list(a.yearweek.values))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-334-e3a7e2620ec6> in <module>()
# ----> 1 emptyyearweek = fullyearweek - list(a.yearweek.values)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
if ( <maxyearweek)
    for i in fullyearweek:
        inputyearweek = i+1
        fullyearweek.append(inputyearweek)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-282-8cc8ad789d13> in <module>()
#       1 for i in fullyearweek:
#       2     inputyearweek = i+1
# ----> 3     fullyearweek.append(inputyearweek)
#       4
#
# KeyboardInterrupt:

# %%
a = actualData.loc[0:0,:].yearweek - actualData.loc[1:1,:].yearweek

# %%
actualData.loc[0:0,:].yearweek.values
# Out:
# array([201306], dtype=int64)

# %%
a
# Out:
# 0   NaN
# 1   NaN
# Name: yearweek, dtype: float64

# %%
for i in a:
    value1 = i
value1
# Out:
# 201306

# %%
a
# Out:
# array([201306], dtype=int64)

# %%
for i in actualData['yearweek']:
    a  = actualData.loc[i:i,:].yearweek.values

# %%
b = actualData.loc[1:1,:].yearweek

# %%
for i in  actualData.loc[i:i,:].yearweek:
    for j in actualData.loc[i+1:i+1,:].yearweek:
        value1 = j

# %%
value1
# Out:
# 201306

# %%
value1
# Out:
# 201306

# %%
value2 - value1
# Out:
# 1

# %%
actualData.loc[1:1,:].yearweek
# Out:
# 1    201307
# Name: yearweek, dtype: int64

# %%
groupData['yearweek'].min()
# Out:
# regionSeg1  productSeg2  regionSeg2   regionSeg3  productSeg3
# A01         PG01         SALESID0001  SITEID0001  ITEM0001       201301
#                                                   ITEM0002       201301
#                                                   ITEM0003       201302
#                                                   ITEM0004       201301
#                                                   ITEM0005       201301
#                                                   ITEM0006       201301
#                                                   ITEM0106       201301
#                                                   ITEM0107       201301
#                                                   ITEM0108       201301
#                                                   ITEM0109       201331
#                                                   ITEM0110       201330
#                                                   ITEM0111       201333
# ...

# %%
eachData = groupData.get_group(list(groupData.groups)[1])

eachData
# Out:
#       regionSeg1  productSeg1 productSeg2   regionSeg2  regionSeg3  \
# 28688        A01          NaN        PG01  SALESID0001  SITEID0001
# 28689        A01          NaN        PG01  SALESID0001  SITEID0001
# 28690        A01          NaN        PG01  SALESID0001  SITEID0001
# 28691        A01          NaN        PG01  SALESID0001  SITEID0001
# 28692        A01          NaN        PG01  SALESID0001  SITEID0001
# 28693        A01          NaN        PG01  SALESID0001  SITEID0001
# 28694        A01          NaN        PG01  SALESID0001  SITEID0001
# 28695        A01          NaN        PG01  SALESID0001  SITEID0001
# 28696        A01          NaN        PG01  SALESID0001  SITEID0001
# 28697        A01          NaN        PG01  SALESID0001  SITEID0001
# 28698        A01          NaN        PG01  SALESID0001  SITEID0001
# 28699        A01          NaN        PG01  SALESID0001  SITEID0001
# 28700        A01          NaN        PG01  SALESID0001  SITEID0001
# ...

# %%
meanValue.head()
# Out:
#            productSeg1  yearweek        qty
# year week
# 2013 1             NaN  201301.0   6.977376
#      2             NaN  201302.0   6.808696
#      3             NaN  201303.0   8.467153
#      4             NaN  201304.0  10.013825
#      5             NaN  201305.0   9.635347

# %%
a
# Out:
# Empty DataFrame
# Columns: [qty]
# Index: []

# %%
a = meanValue[meanValue.yearweek > 201603]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-ec6c5cea0306> in <module>()
# ----> 1 a = meanValue[meanValue.yearweek > 201603]
#
# TypeError: '>' not supported between instances of 'SeriesGroupBy' and 'int'

# %%
a = pd.DataFrame(meanValue)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     391             try:
# --> 392                 arr = np.array(data, dtype=dtype, copy=copy)
#     393             except (ValueError, TypeError) as e:
#
# ValueError: cannot copy sequence with size 2696 to array axis with dimension 0
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-75bb3fd6e7e1> in <module>()
# ----> 1 a = pd.DataFrame(meanValue)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     394                 exc = TypeError('DataFrame constructor called with '
# ...

# %%
ttt = meanValue['yearweek'].value_counts(201603)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-81-68f40e265990> in <module>()
# ----> 1 ttt = meanValue['yearweek'].value_counts(201603)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in value_counts(self, normalize, sort, ascending, bins, dropna)
#    3500
#    3501         # multi-index components
# -> 3502         labels = list(map(rep, self.grouper.recons_labels)) + [llab(lab, inc)]
#    3503         levels = [ping.group_index for ping in self.grouper.groupings] + [lev]
#    3504         names = self.grouper.names + [self._selection_name]
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in <lambda>(lab, inc)
#    3470         if bins is None:
#    3471             lab, lev = algorithms.factorize(val, sort=True)
# -> 3472             llab = lambda lab, inc: lab[inc]
#    3473         else:
#    3474
#
# ...

# %%
meanValue = actualData.groupby(['productSeg2', 'regionSeg2', 'productSeg3','yearweek'], as_index=True)['qty'].mean()

# %%
meanValue.reset_index()
# Out:
#       productSeg2   regionSeg2 productSeg3  yearweek       qty
# 0            PG01  SALESID0001    ITEM0001    201301  1.600000
# 1            PG01  SALESID0001    ITEM0001    201302  2.000000
# 2            PG01  SALESID0001    ITEM0001    201303  1.000000
# 3            PG01  SALESID0001    ITEM0001    201304  2.000000
# 4            PG01  SALESID0001    ITEM0001    201305  2.750000
# 5            PG01  SALESID0001    ITEM0001    201306  2.000000
# 6            PG01  SALESID0001    ITEM0001    201307  2.750000
# 7            PG01  SALESID0001    ITEM0001    201308  1.000000
# 8            PG01  SALESID0001    ITEM0001    201309  1.500000
# 9            PG01  SALESID0001    ITEM0001    201310  1.250000
# 10           PG01  SALESID0001    ITEM0001    201311  1.500000
# 11           PG01  SALESID0001    ITEM0001    201312  1.000000
# 12           PG01  SALESID0001    ITEM0001    201313  1.666667
# 13           PG01  SALESID0001    ITEM0001    201314  1.500000
# ...
