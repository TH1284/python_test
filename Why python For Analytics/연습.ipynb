# %%
a="SEC 20180212 250"

# %%
stockName=a[0:4]

# %%
stockName
# Out:
# 'SEC '

# %%
date=a[4:4+8]

# %%
date
# Out:
# '20180212'

# %%
value=a[4+8+1:]

# %%
value
# Out:
# ' 250'

# %%
b="Sec 2018W28 250"
sn = b[0:4].upper()
print(sn)
# Out:
# SEC

# %%
dat=b[4:4+8].replace('W',"")
print(dat)
# Out:
# 201828

# %%
val=b[4+8:]
print(val)
# Out:
# 250

# %%
c=[120,150,300,500,1000,100,2000]

# %%
n = min(c)

# %%
n
# Out:
# 100

# %%
m = max(c)
m
# Out:
# 2000

# %%
m
# Out:
# 2000

# %%
c
# Out:
# [300, 500, 1000]

# %%
del c[0]

# %%
c.remove(m)

# %%
c
# Out:
# [120, 150, 300, 500, 1000]

# %%
pwd
# Out:
# 'C:\\Users\\SMART-21\\Python_Git\\Why python For Analytics'

# %%
import pandas as pd
customerData = pd.read_csv("./dataset/kopo_region_mst_hangul.csv",encoding='ms949')
customerData
# Out:
#    REGIONID REGIONNAME
# 0       A00       아프리카
# 1       A01         미국
# 2       A02         한국
# 3       A03         독일
# 4       A04        브라질
# 5       A05         아랍
# 6       A06        앙골라
# 7       A07        벨기에
# 8       A08       불가리아
# 9       A09        바레인
# 10      A10        브라질
# 11      A11       볼리비아
# 12      A12        캐나다
# 13      A13        스위스
# 14      A14         칠레
# 15      A15         중국
# 16      A16       콜롬비아
# 17      A17      코스타리카
# 18      A18        덴마크
# 19      A19        알제리
# 20      A20        이집트
# 21      A21        스페인
# 22      A22        핀란드
# 23      A23        프랑스
# 24      A24         영국
# 25      A25         가나
# 26      A26        그리스
# 27      A27          괌
# 28      A28         홍콩
# 29      A29        아이티
# ..      ...        ...
# 43      A43       네덜런드
# 44      A44        멕시코
# 45      A45         네팔
# 46      A46       뉴질랜드
# 47      A47        필리핀
# 48      A48        폴란드
# 49      A49       포르투갈
# 50      A50       루마니아
# ...

# %%
import pandas as pd
customerData = pd.read_csv(E:/Python_ST_EX/dataset/kopo_region_mst.csv)
customerData
# Out:
#   File "<ipython-input-41-a97bb8188d2c>", line 2
#     customerData = pd.read_csv(E:/Python_ST_EX/dataset/kopo_region_mst.csv)
#                                 ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
B=pd.read_csv("./dataset/kopo_product_volume.csv")
B
# Out:
#     REGIONID PRODUCTGROUP  YEARWEEK   VOLUME
# 0        A01       ST0001    201415   810144
# 1        A01       ST0002    201415   128999
# 2        A01       ST0001    201418   671464
# 3        A01       ST0002    201418   134467
# 4        A01       ST0001    201413   470040
# 5        A01       ST0002    201413   140297
# 6        A01       ST0001    201411   524787
# 7        A01       ST0002    201411   145509
# 8        A01       ST0001    201416   764927
# 9        A01       ST0002    201416   140313
# 10       A01       ST0001    201419   682757
# 11       A01       ST0002    201419   128668
# 12       A01       ST0001    201414   428195
# 13       A01       ST0002    201414   137488
# 14       A01       ST0001    201412   486509
# 15       A01       ST0001    201417   697502
# 16       A01       ST0002    201417   127163
# 17       A01       ST0001    201407   620392
# 18       A01       ST0002    201407   146476
# 19       A01       ST0001    201410   511679
# ...

# %%
B.columns=['SALESID','PRODUCTGROUP','YEARWEEK','VOLUME']
B
# Out:
#     SALESID PRODUCTGROUP  YEARWEEK   VOLUME
# 0       A01       ST0001    201415   810144
# 1       A01       ST0002    201415   128999
# 2       A01       ST0001    201418   671464
# 3       A01       ST0002    201418   134467
# 4       A01       ST0001    201413   470040
# 5       A01       ST0002    201413   140297
# 6       A01       ST0001    201411   524787
# 7       A01       ST0002    201411   145509
# 8       A01       ST0001    201416   764927
# 9       A01       ST0002    201416   140313
# 10      A01       ST0001    201419   682757
# 11      A01       ST0002    201419   128668
# 12      A01       ST0001    201414   428195
# 13      A01       ST0002    201414   137488
# 14      A01       ST0001    201412   486509
# 15      A01       ST0001    201417   697502
# 16      A01       ST0002    201417   127163
# 17      A01       ST0001    201407   620392
# 18      A01       ST0002    201407   146476
# 19      A01       ST0001    201410   511679
# ...

# %%
import timeit
start =timeit.default_timer()

# %%
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# Time:  95.85855490799986

# %%
import pandas as pd
qtyList = pd.read_csv("./dataset/kopo_channel_seasonality_new.csv")["QTY"].tolist()
qtyList
# Out:
# [71.0,
#  22275.0,
#  4463.0,
#  0.0,
#  23.0,
#  14.0,
#  1186.0,
#  7.0,
#  101.0,
#  336.0,
#  0.0,
#  11492.0,
#  825.0,
#  0.0,
#  560.0,
#  103.0,
#  0.0,
#  740.0,
#  394.0,
#  2550.0,
#  4.0,
#  36549.0,
#  4773.0,
#  146.0,
#  5.0,
#  9.0,
#  109.0,
#  1195.0,
#  15028.0,
#  1319.0,
#  786.0,
#  97.0,
#  695.0,
#  3.0,
#  0.0,
#  0.0,
#  484.0,
#  657.0,
#  1191.0,
#  385.0,
#  21679.0,
#  879.0,
#  203.0,
#  75.0,
#  1173.0,
#  1235.0,
#  156.0,
#  23768.0,
#  105.0,
#  1513.0,
#  59.0,
#  4436.0,
#  4.0,
#  5449.0,
#  13394.0,
#  119281.0,
#  21350.0,
#  6940.0,
#  8022.0,
#  3823.0,
#  3697.0,
#  0.0,
#  100.0,
#  3216.0,
#  1748.0,
#  -1.0,
#  20184.0,
#  1404.0,
#  488.0,
#  12.0,
#  107.0,
#  54.0,
#  5496.0,
#  168.0,
#  885.0,
#  923.0,
#  335.0,
#  1066.0,
#  11.0,
#  189.0,
#  1728.0,
#  2462.0,
#  1012.0,
#  1469.0,
#  21588.0,
#  610.0,
#  226.0,
#  122.0,
#  1398.0,
#  5838.0,
#  151.0,
#  383.0,
#  69.0,
#  1304.0,
#  0.0,
#  32110.0,
#  920.0,
#  0.0,
# ...

# %%
a=min(qtyList)

# %%
a
# Out:
# -364.0

# %%
b=max(qtyList)
b
# Out:
# 1663206.0

# %%
aa = qtyList.index(a)

# %%
bb = qtyList.index(b)

# %%
del qtyList[aa]

# %%
del qtyList[bb]

# %%
sum1= sum(qtyList)
sum1
# Out:
# 1113937329.19

# %%
len(qtyList)
# Out:
# 124656

# %%
avg = sum(qtyList)/len(qtyList)

# %%
avg
# Out:
# 8936.090755278527

# %%
import pandas as pd

# %%
customerdata = pd.read_csv(./dataset/kopo_product_volume.csv)
