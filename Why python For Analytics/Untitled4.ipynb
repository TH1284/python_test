# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

# %%
url = "http://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=OWRkMDdhMjY4ODkxMjFiNDY3MjFkYTE4MjcxMWU2OWU=&format=json&jsonVD=Y&userStatsId=qlwlel1284/116/DT_MLTM_842/2/1/20190418172307&prdSe=Y&startPrdDe=2017&endPrdDe=2017"

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
json = response.json()

# %%
df = json_normalize(json)
df
# Out:
#                  C1                       C1_NM  \
# 0   13102871112A.02                          합계
# 1   13102871112A.02                          합계
# 2   13102871112A.04                     공공주택사업자
# 3   13102871112A.04                     공공주택사업자
# 4   13102871112A.04                     공공주택사업자
# 5   13102871112A.04                     공공주택사업자
# 6   13102871112A.04                     공공주택사업자
# 7   13102871112A.04                     공공주택사업자
# 8   13102871112A.06                     기업형임대주택
# 9   13102871112A.06                     기업형임대주택
# 10  13102871112A.06                     기업형임대주택
# 11  13102871112A.06                     기업형임대주택
# 12  13102871112A.07                     준공공임대주택
# 13  13102871112A.07                     준공공임대주택
# 14  13102871112A.07                     준공공임대주택
# 15  13102871112A.07                     준공공임대주택
# 16  13102871112A.08                      단기임대주택
# 17  13102871112A.08                      단기임대주택
# ...

# %%
df.to_csv("./연도별 임대주택사업자현황2017.csv",encoding="ms949")
