# %%
tvList = [ 'UN40EN001', 'UN40EN002', 'UN40EN003', 'UN40EN004' ]

# %% [markdown]
# range(0,4)

# %% [markdown]
# prefix= "LED_TV"

# %% [markdown]
# for i in range(0,4):
#     tvList[i] = prefix + tvList[i]

# %% [markdown]
# tvList[0] = prefix + tvList[0]
# tvList[1] = prefix + tvList[1]
# tvList[2] = prefix + tvList[2]

# %% [markdown]
# tvList

# %%
prefix= "LED_TV"

# %%
i = 0
tvListLen = len(tvList)

# %%
while(i < 4):
     tvList[i] = prefix + tvList[i]
        i = i+1
# Out:
#   File "<ipython-input-38-f3bf1814ee08>", line 3
#     i = i+1
#     ^
# IndentationError: unexpected indent

# %%
n=5
print("{0}단 시작".format(n))
# Out:
# 5단 시작

# %%
for n in range(1,3)
    print ("{0}단 시작".format(n))
for i in (1,10):
    print ("{0} * {1} = {2} ".format(n, i, n*i))
# Out:
#   File "<ipython-input-44-3ff79e4514d0>", line 1
#     for n in range(1,3)
#                        ^
# SyntaxError: invalid syntax

# %%
n=1

# %%
print("{0}단 시작".format(n))
# Out:
# 1단 시작

# %%
i=3

# %%
print ("{0} * {1} = {2} ".format(n, i, n*i))
# Out:
# 1 * 3 = 3

# %%
c =[1,2,3,4]

# %%
c
# Out:
# [1, 2, 3, 4]

# %%
type(c)
# Out:
# list

# %%
y="2017w42"

# %%
y.split("w")[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-22e0adad2d45> in <module>
# ----> 1 y.split("w")[0]
#
# AttributeError: 'list' object has no attribute 'split'

# %% [markdown]
# #자료형

# %%
import pandas as pd

# %%
customerData = pd.read_csv("./dataset/kopo_customerdata.csv")
customerTotalList = customerData["TOTAL_AMOUNT"].tolist()
customerTotalList
# Out:
# [30300,
#  46500,
#  22700,
#  31400,
#  44900,
#  38300,
#  19900,
#  14800,
#  24400,
#  30400,
#  30300,
#  34300,
#  14900,
#  16300,
#  25000,
#  27500,
#  18200,
#  40200,
#  74600,
#  42700,
#  14900,
#  58700,
#  16000,
#  17800,
#  26800,
#  14000,
#  31800,
#  16000,
#  37600,
#  32800,
#  176600,
#  16200,
#  102000,
#  56800,
#  14700,
#  14800,
#  2500,
#  23600,
#  38100,
#  82300,
#  62900,
#  5000,
#  16100,
#  40900,
#  14600,
#  28600,
#  12300,
#  37800,
#  32600,
#  16100,
#  18400,
#  17700,
#  9400,
#  37400,
#  8800,
#  26600,
#  20900,
#  15800,
#  14800,
#  20500,
#  19700,
#  39900,
#  122900,
#  33000,
#  12100,
#  14700,
#  48400,
#  51900,
#  17400,
#  26500,
#  12800,
#  15500,
#  21400,
#  15300,
#  36000,
#  49000,
#  35800,
#  16900,
#  43000,
#  28200,
#  45100,
#  18200,
#  20600,
#  23900,
#  14500,
#  70000,
#  15800,
#  6600,
#  40500,
#  17000,
#  43800,
#  146800,
#  86900,
#  19200,
#  17100,
#  18800,
#  24700,
#  17500,
#  25100,
#  19000,
# ...

# %%
k = min(customerTotalList)
k
# Out:
# 0

# %%
k2 = max(customerTotalList)
k2
# Out:
# 3103500

# %%
kk = customerTotalList.index(k)
kk
# Out:
# 2017

# %%
kk2 = customerTotalList.index(k2)
kk2
# Out:
# 38587

# %%
del customerTotalList[kk]

# %%
del customerTotalList[kk2]

# %%
sum1 = sum(customerTotalList)
sum1
# Out:
# 10568701400

# %%
len1= len(customerTotalList)
len1
# Out:
# 299998

# %%
ag= sum1/len1
ag
# Out:
# 35229.23952826352

# %%
tvList2 = ['UN40EN001', 'LEDTV_UN40EN002', 'LEDTV_LEDTV_UN40EN003', 'UN40EN004']
preFix = "LEDTV_"

# %%
i=0
while(i < 4):
    prefixCount = tvList2[i].count(preFix)
    prefixCount

    preFix + tvList2[i]

    ## 만약 count가 0이면 prefix 추가
    if(prefixCount == 0):
        tvList2[i] = preFix + tvList2[i]
    ## 만약 count가 1개면 유지
    elif(prefixCount == 1):
        tvList2[i] = tvList2[i]
    ## 만약 count가 2개이상이면
    ## prefix제거 후 prefix 한개 추가
    else:
        tvList2[i] = tvList2[i].replace(preFix, "")
        tvList2[i] = preFix + tvList2[i]
    i=i+1

# %%
tvList2
# Out:
# ['LEDTV_UN40EN001', 'LEDTV_UN40EN002', 'LEDTV_UN40EN003', 'LEDTV_UN40EN004']

# %%
aaa = "LEDTV_LEDTV_LEDTV_AAA"

# %%
aaa.replace("LEDTV_","")
# Out:
# 'AAA'

# %%
i = 0
tvListLen = len(tvList2)

# %%
tvListLen = len(tvList2)
while(i < tvListLen):
    preFixCnt = tvList2[i].count
    if(preFixCnt==0):
        tvList2[i] = preFix + tvList2[i]
        elif(preFixCnt==1):
            tvLis2t[i] = tvList2[i]
        else:
            tvList2[i] = tvList2[i].replace(preFix*preFixCnt,preFix)
# Out:
#   File "<ipython-input-82-7fa570a8d53f>", line 6
#     elif(preFixCnt==1):
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 함수사용

# %%
a = 10
b = 5.3
display2Digit = a/b
(1.8867924528301887)
# Out:
# 1.8867924528301887

# %%
target = 1.8867924528301887
target_step1 = target * 100
target_step1
# Out:
# 188.67924528301887

# %%
target_step2 = round(target_step1)
target_step2
# Out:
# 189

# %%
target_step3 = target_step2/100
target_step3
# Out:
# 1.89

# %%
def roundTwo(value):
    step1 = value * 100
    step2 = round(step1)
    step3 = step2/100
return step3

a = 10
b = 5.3
display2Dgit = a/b
print(display2Dgit)
answer = roundRwo(display2Dgit)
answer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# cell_name in async-def-wrapper()
#
# NameError: name 'step3' is not defined

# %%
testValue = 1.234123

# %%
round2Digit(testValue)

# %%
value = 1.222533
digitp3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-976b573162c8> in <module>
#       1 value = 1.222533
# ----> 2 digitp3
#
# NameError: name 'digitp3' is not defined

# %%
List2 = [1,2,3,4,5]

# %%
def List1(ListValue):
    max1 = max(ListValue)
    min1 = min(ListValue)
    
    ListValue.remove(max1)
    ListValue.remove(min1)
    
    avg = sum(ListValue) / len(ListValue)
    return avg

# %%
List1(List2)
# Out:
# 3.0

# %%
name = input("성함을 입력하세요:")
print(name)

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# PANDAS 패키지 불러오기
import pandas as pd 
import pymysql 
from sqlalchemy import create_engine 
 





# DB 커넥션 열기
engine = create_engine('mysql+pymysql://kopo:kopo@192.168.110.111:3306/kopo') 

# DB 테이블을 읽어 Data Frame 변수에 저장하기
selloutData = pd.read_sql_query('SELECT * FROM kopo_product_volume', engine)
selloutData

# 컬럼해더 재정의
selloutData.columns = ['REGIONID','PRODUCTGROUP','YEARWEEK','VOLUME']
selloutData

# 데이터 저장
resultname='mysqlresult_TH'
selloutData.to_sql(resultname, engine, if_exists='replace', index=False)

# %%
import pandas as pd
import cx_Oracle
from sqlalchemy import create_engine

# %%
engine_oracle = create_engine('oracle+cx_oracle://TH:TH@192.168.110.21:1522/xe')

# %%
selloutData = pd.read_sql_query('SELECT * FROM kopo_product_volume', engine_oracle)
selloutData
# Out:
#     regionid productgroup yearweek   volume
# 0        A01       ST0002   201512   151750
# 1        A01       ST0001   201520   645626
# 2        A01       ST0002   201520   125863
# 3        A01       ST0001   201515   810144
# 4        A01       ST0002   201515   128999
# 5        A01       ST0001   201518   671464
# 6        A01       ST0002   201518   134467
# 7        A01       ST0001   201513   470040
# 8        A01       ST0002   201513   140297
# 9        A01       ST0001   201511   524787
# 10       A01       ST0002   201511   145509
# 11       A01       ST0001   201516   764927
# 12       A01       ST0002   201516   140313
# 13       A01       ST0001   201519   682757
# 14       A01       ST0002   201519   128668
# 15       A01       ST0001   201514   428195
# 16       A01       ST0002   201514   137488
# 17       A01       ST0001   201512   486509
# 18       A01       ST0001   201517   697502
# 19       A01       ST0002   201517   127163
# ...

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# %%
engine_postgres = create_engine('postgresql://postgres:postgres@192.168.110.111:5432/kopo')

# %%
# selloutData = pd.read_sql_query('SELECT * FROM kopo_product_volume', engine)
# selloutData.head()
resultname='postgres_TH'
selloutData.to_sql(resultname, engine_postgres, if_exists='replace', index=False)
